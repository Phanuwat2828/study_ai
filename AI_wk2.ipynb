# %% [markdown]
# ## This week2 study doing `BFS` & `DFS`
# ## pip install ..

# %%
pip install collection

# %% [markdown]
# การใช้งานโครงสร้างต้นไม้
# ### โครงสร้างแรก คือ `BSF Tree`

# %%
#66011212124 Phanuwat Khamtha
from collections import deque
class Node:
    def __init__(self,data):
        self.data = data # ข้อมูลที่เก็บใน Node
        self.children = [] # Node ลูก

    def add_child(self,child_node):
        self.children.append(child_node) # เพิ่ม Node ลูก
    
    def __repr__(self): # แสดงข้อมูล Node
        return f"Node({self.data})"
    
def bsf_tree_search(root_node,target_data):
    if root_node is None:
        return None # กรณีที่ Node รากเป็น None
    
    queue = deque([root_node]) # สร้างคิวเริ่มต้นด้วย Node ราก
    print(f"เริ่มการค้นหาแบบ BFS  Target: {target_data}...")
    
    while queue:
        
        current_node = queue.popleft() # นำ Node แรกออกจากคิว
        print(f"สำรวจ Node: {current_node.data}")
        if current_node.data == target_data: # ตรวจสอบข้อมูล
            return current_node # พบ Node ที่ต้องการ
        for child in current_node.children:
            queue.append(child) # เพิ่ม Node ลูกลงในคิว
    return None # ไม่พบ Node ที่ต้องการ

# %%
#66011212124 Phanuwat Khamtha
# สร้างต้นไม้ตัวอย่าง
root = Node("A")
node_b = Node("B")
node_c = Node("C")
node_d = Node("D")
node_e = Node("E")
node_f = Node("F")
node_g = Node("G")
node_h = Node("H")


# สร้างความสัมพันธ์ระหว่าง Node
root.add_child(node_b)
root.add_child(node_c)  
node_b.add_child(node_d)
node_b.add_child(node_e)
node_c.add_child(node_f)
node_c.add_child(node_g)
node_e.add_child(node_h)


# เรียกใช้ฟังก์ชันค้นหา
while True:
    goal = input("ป้อนข้อมูล Node ที่ต้องการค้นหา (หรือ 'exit' เพื่อออก): ")
    if goal=="":
        break
    result_node = bsf_tree_search(root,goal)
    print("ผลลัพธ์การค้นหา:")
    if result_node:
        print("พบ Node:", result_node.data)
    else:
        print("ไม่พบ Node ที่ต้องการค้นหา")
# Out:
# ป้อนข้อมูล Node ที่ต้องการค้นหา (หรือ 'exit' เพื่อออก):  E
# เริ่มการค้นหาแบบ BFS  Target: E...
# สำรวจ Node: A
# สำรวจ Node: B
# สำรวจ Node: C
# สำรวจ Node: D
# สำรวจ Node: E
# ผลลัพธ์การค้นหา:
# พบ Node: E
# ป้อนข้อมูล Node ที่ต้องการค้นหา (หรือ 'exit' เพื่อออก):  F
# เริ่มการค้นหาแบบ BFS  Target: F...
# สำรวจ Node: A
# สำรวจ Node: B
# สำรวจ Node: C
# สำรวจ Node: D
# สำรวจ Node: E
# สำรวจ Node: F
# ผลลัพธ์การค้นหา:
# พบ Node: F

# %% [markdown]
# ### โครงสร้างแรก คือ `BSF Graph`

# %%
graph = {
'S': ['A', 'B','C'],
'B': ['F','G'],
'A': ['D', 'E'],
'C': ['H'],
'H': ['I', 'J'],
'I': ['M', 'L', 'K']
}

# %%
#66011212124 Phanuwat Khamtha
from collections import deque
import time 



def bfs_graph_search(graph, start, goal):
    if start not in graph:
        print("Start node not in graph")
        return False
    queue = deque([start])
    visited = {start}
    print(f"Starting BFS from {start} to find {goal}")
    while queue:
        print("queue: ", queue)
        current = queue.popleft()
        print("visited: ", current)
        if current == goal:
            print(f"Goal {goal} found!")
            return True
        for neighbor in graph[current]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)
        time.sleep(0.5)  # Pause for visualization
    return False

# %%
#66011212124 Phanuwat Khamtha
def solution(start, goal):
    found = bfs_graph_search(graph, start, goal)
    if found:
        sol = "Solution found!" + goal
    else:
        sol = "No solution found." + goal
    print(sol)
solution('S', 'I')
# Out:
# Starting BFS from S to find I
# queue:  deque(['S'])
# visited:  S
# queue:  deque(['A', 'B', 'C'])
# visited:  A
# queue:  deque(['B', 'C', 'D', 'E'])
# visited:  B
# queue:  deque(['C', 'D', 'E', 'F', 'G'])
# visited:  C
# queue:  deque(['D', 'E', 'F', 'G', 'H'])
# visited:  D
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 9
#       7         sol = "No solution found." + goal
#       8     print(sol)
# ----> 9 solution('S', 'I')
#
# Cell In[8], line 3, in solution(start, goal)
#       2 def solution(start, goal):
# ----> 3     found = bfs_graph_search(graph, start, goal)
#       4     if found:
#       5         sol = "Solution found!" + goal
#
# Cell In[7], line 21, in bfs_graph_search(graph, start, goal)
#      19     print(f"Goal {goal} found!")
#      20     return True
# ---> 21 for neighbor in graph[current]:
#      22     if neighbor not in visited:
#      23         visited.add(neighbor)
#
# KeyError: 'D'

# %% [markdown]
# ### การใช้ `DFS Graph`

# %%
#66011212124 Phanuwat Khamtha
from collections import deque
import time 
graph = {
'A': ['B', 'C', 'D'],
'B': ['E', 'F'],
'C': ['G','H'],
'D': [],
'E': ['I','J'],
'F': ['K'],
'G': ['L','M'],
'H': [],
'I': [],
'J': [],
'K': [],
'L': [],
'M': []
}

def dfs_graph_search(graph, start, goal):
    if start not in graph:
        print("Start node not in graph")
        return False
    stack = [start]
    visited = {start}
    order = []
    print(f"Starting DFS from {start} to find {goal}")
    while stack:
        print("stack : ",stack);
        current = stack.pop()
        order.append(current)
        print("visiting: ", current)
        if current == goal: 
            print(f"ผลลัพธ์ : พบเป้าหมาย ",goal)
            print(order)
            print("\n" + "="*50 + "\n")
            return True
        for neighbor in reversed(graph.get(current, [])):
            if neighbor not in visited:
                visited.add(neighbor)
                stack.append(neighbor)
        time.sleep(0.5)  # Pause for visualization
    print(f"ผลลัพธ์ : ไม่พบเป้าหมาย ",goal)
    return False

# %%
#66011212124 Phanuwat Khamtha
goal = 'I'
print(f"[ตัวอย่างที่ 1: ค้นหาโหนด {goal} (อยู่ลึก) ]")
found = dfs_graph_search(graph, 'A', goal)

# ตัวอย่างที่2: ค้นหาโหนด 'Z' (ไม่พบ)
goal='Z'
print(f"[ตัวอย่างที่ 2: ค้นหาโหนด {goal} (ไม่พบ)]")
found = dfs_graph_search(graph, 'A', goal)
# Out:
# [ตัวอย่างที่ 1: ค้นหาโหนด I (อยู่ลึก) ]
# Starting DFS from A to find I
# stack :  ['A']
# visiting:  A
# stack :  ['D', 'C', 'B']
# visiting:  B
# stack :  ['D', 'C', 'F', 'E']
# visiting:  E
# stack :  ['D', 'C', 'F', 'J', 'I']
# visiting:  I
# ผลลัพธ์ : พบเป้าหมาย  I
# ['A', 'B', 'E', 'I']
#
# ==================================================
#
# [ตัวอย่างที่ 2: ค้นหาโหนด Z (ไม่พบ)]
# Starting DFS from A to find Z
# stack :  ['A']
# visiting:  A
# stack :  ['D', 'C', 'B']
# visiting:  B
# stack :  ['D', 'C', 'F', 'E']
# visiting:  E
# stack :  ['D', 'C', 'F', 'J', 'I']
# visiting:  I
# stack :  ['D', 'C', 'F', 'J']
# visiting:  J
# stack :  ['D', 'C', 'F']
# visiting:  F
# stack :  ['D', 'C', 'K']
# visiting:  K
# stack :  ['D', 'C']
# visiting:  C
# stack :  ['D', 'H', 'G']
# visiting:  G
# stack :  ['D', 'H', 'M', 'L']
# visiting:  L
# stack :  ['D', 'H', 'M']
# visiting:  M
# stack :  ['D', 'H']
# visiting:  H
# stack :  ['D']
# visiting:  D
# ผลลัพธ์ : ไม่พบเป้าหมาย  Z
